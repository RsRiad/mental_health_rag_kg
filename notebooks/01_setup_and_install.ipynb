# %% [markdown]
# # 01: Setup and Installation
#
# Run this notebook first to mount Google Drive and install all dependencies.

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Set project path
PROJECT_PATH = '/content/drive/MyDrive/mental_health_rag_kg'
import os
os.chdir(PROJECT_PATH)
print('Working directory:', os.getcwd())
# Out:
# Working directory: /content/drive/MyDrive/mental_health_rag_kg

# %%
# Install dependencies
# !pip install -q transformers torch datasets sentence-transformers faiss-cpu rdflib PyYAML python-dotenv requests beautifulsoup4 lxml numpy pandas tqdm biopython accelerate scikit-learn matplotlib seaborn
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 57.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.4/615.4 kB 30.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 84.1 MB/s eta 0:00:00:00:01

# %%
# Verify imports
import torch
import transformers
import faiss
import rdflib
print('PyTorch:', torch.__version__)
print('Transformers:', transformers.__version__)
print('FAISS imported successfully')
print('RDFLib imported successfully')
# Out:
# PyTorch: 2.10.0+cpu
# Transformers: 5.0.0
# FAISS imported successfully
# RDFLib imported successfully

# %%
# Create .env file with your API keys (run once, then delete cell)
env_content = """PUBMED_API_KEY=96fbcb483eba695282324bb2540598df2808
SAMBANOVA_API_KEY=6a4ba5ba-98da-4d8e-ad3f-58e3b4801a82
SAMBANOVA_URL=https://api.sambanova.ai/v1/chat/completions
SAMBANOVA_MODEL=Meta-Llama-3.3-70B-Instruct
"""
with open('.env', 'w') as f:
    f.write(env_content)
print('.env file created.')
# Out:
# .env file created.

# %%
# Load environment variables
from dotenv import load_dotenv
load_dotenv()
import os
print('SambaNova Key exists:', bool(os.getenv('SAMBANOVA_API_KEY')))
# Out:
# SambaNova Key exists: True
