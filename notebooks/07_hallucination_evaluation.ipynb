# %%
"""
# 07: Hallucination Mitigation Evaluation

#Compare RAG-only vs RAG+KG hallucination rates.
"""
# # Mount Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# # Set project path
PROJECT_PATH = '/content/drive/MyDrive/mental_health_rag_kg'

print('Working directory:', os.getcwd())
import sys
sys.path.append('/content/drive/MyDrive/mental_health_rag_kg')
import os
os.chdir(PROJECT_PATH)

from src.hallucination_evaluator import HallucinationEvaluator

# Initialize evaluator
evaluator = HallucinationEvaluator(output_dir='outputs/hallucination_eval')

# Run standard evaluation (KG pipeline only)
print("=== RUNNING KG PIPELINE EVALUATION ===")
metrics = evaluator.run_evaluation(verbose=True)

# Run comparative evaluation (RAG-only vs RAG+KG)
print("\n=== RUNNING COMPARATIVE EVALUATION ===")
comparison = evaluator.run_comparative_evaluation(verbose=False)

# Combined summary
print(f"\n{'='*60}")
print("FINAL HALLUCINATION MITIGATION RATE")
print(f"{'='*60}")
print(f"Mitigation Rate (KG pipeline): {metrics['mitigation_rate']:.1%}")
print(f"Relative Reduction (vs baseline): {comparison['relative_reduction']:.1%}")
print(f"{'='*60}")
# Out:
# Working directory: /content/drive/MyDrive/mental_health_rag_kg
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_19698/1343210293.py in <cell line: 0>()
#      17 os.chdir(PROJECT_PATH)
#      18
# ---> 19 from src.hallucination_evaluator import HallucinationEvaluator
#      20
#      21 # Initialize evaluator
#
# /content/drive/MyDrive/mental_health_rag_kg/src/__init__.py in <module>
# ----> 1 from .pipeline import MentalHealthPipeline
#       2 from .kg_engine import KGEngine
#       3 from .rag_engine import RAGEngine
#       4 from .llm_client import LLMClient
#       5 from .safety_checker import SafetyChecker
#
# /content/drive/MyDrive/mental_health_rag_kg/src/pipeline.py in <module>
#      10 from src.safety_checker import SafetyChecker
#      11 from src.input_processor import InputProcessor
# ---> 12 from src.rag_engine import RAGEngine
# ...

# %% [markdown]
# """
# # 07: Hallucination Mitigation Evaluation
#
# Compare RAG-only vs RAG+KG hallucination rates.
# """

# %%
import sys
sys.path.append('/content/drive/MyDrive/mental_health_rag_kg')
import os
os.chdir('/content/drive/MyDrive/mental_health_rag_kg')

# %%
from src.hallucination_evaluator import HallucinationEvaluator

# %%
# Initialize evaluator
evaluator = HallucinationEvaluator(output_dir='outputs/hallucination_eval')

# %%
# Run standard evaluation (KG pipeline only)
print("=== RUNNING KG PIPELINE EVALUATION ===")
metrics = evaluator.run_evaluation(verbose=True)

# %%
# Run comparative evaluation (RAG-only vs RAG+KG)
print("\n=== RUNNING COMPARATIVE EVALUATION ===")
comparison = evaluator.run_comparative_evaluation(verbose=False)

# %%
# Combined summary
print(f"\n{'='*60}")
print("FINAL HALLUCINATION MITIGATION RATE")
print(f"{'='*60}")
print(f"Mitigation Rate (KG pipeline): {metrics['mitigation_rate']:.1%}")
print(f"Relative Reduction (vs baseline): {comparison['relative_reduction']:.1%}")
print(f"{'='*60}")
